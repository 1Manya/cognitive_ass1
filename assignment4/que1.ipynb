# %%
import numpy as np
arr=np.array([1,2,3,4,5])
print("original array",arr)
# Out:
# original array [1 2 3 4 5]

# %%
#a
arr_add=arr+2
print("array after adding 2",arr_add)
# Out:
# array after adding 2 [3 4 5 6 7]

# %%
#b
arr_mul=arr*2
print("array after multiplying 2",arr_mul)
# Out:
# array after multiplying 2 [ 2  4  6  8 10]

# %%
#c
arr_div=arr/2
print("array after dividing 2",arr_div)
# Out:
# array after dividing 2 [0.5 1.  1.5 2.  2.5]
